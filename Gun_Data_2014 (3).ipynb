# %%
 # Import Dependencies
import pandas as pd 
import numpy as np
import csv

jan_csv = "/Users/kyriakikaralis/downloads/jan14_data.csv"
feb_csv = "/Users/kyriakikaralis/downloads/feb14_data.csv"
mar_csv = "/Users/kyriakikaralis/downloads/mar14_data.csv"
apr_csv = "/Users/kyriakikaralis/downloads/april14_data.csv"
jun_csv = "/Users/kyriakikaralis/downloads/june14_data.csv"
aug_csv = "/Users/kyriakikaralis/downloads/aug14_data.csv"
sep_csv = "/Users/kyriakikaralis/downloads/sept14_data.csv"
oct_csv = "/Users/kyriakikaralis/downloads/oct14_data.csv"
nov_csv = "/Users/kyriakikaralis/downloads/nov14_data.csv"
dec_csv = "/Users/kyriakikaralis/downloads/dec14_data.csv"

# %%
jan_df = pd.read_csv(jan_csv)

jan_df.head()
# Out:
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         4L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         6         4M       152
# 4         1        66        23         1         6E        95
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR            00602
# ...

# %%
feb_df = pd.read_csv(feb_csv)
feb_df.head()
# Out:
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         4L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         1         6E        95
# 4         1        66        23         6         4M       152
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR            00602
# ...

# %%
mar_df = pd.read_csv(mar_csv)
mar_df.head()
# Out:
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         4L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         6         4M       152
# 4         1        66        23         1         6E        95
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR            00602
# ...

# %%
apr_df = pd.read_csv(apr_csv)
apr_df.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         4L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         6         4M       152
# 4         1        66        23         1         6E        95
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# ...

# %%
#merging Jan thru April into one dataframe

df1 = pd.DataFrame(jan_df)
df2 = pd.DataFrame(feb_df)
df3 = pd.DataFrame(mar_df)
df4 = pd.DataFrame(apr_df)

merged_df = pd.concat([df1, df2, df3, df4])

merged_df.head()
# Out:
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         4L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         6         4M       152
# 4         1        66        23         1         6E        95
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR            00602
# ...

# %%
jun_df = pd.read_csv(jun_csv)

jun_df.head()
# Out:
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         4L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         1         6E        95
# 4         1        66        23         6         4M       152
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR              602
# ...

# %%
aug_df = pd.read_csv(aug_csv)

aug_df.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         4L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         6         4M       152
# 4         1        66        23         1         6E        95
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# ...

# %%
sep_df = pd.read_csv(sep_csv)

sep_df.head()
# Out:
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         4L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         6         4M       152
# 4         1        66        23         1         6E        95
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR              602
# ...

# %%
oct_df = pd.read_csv(oct_csv)

oct_df.head()
# Out:
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0       1.0      66.0       3.0       1.0         7L     150.0
# 1       1.0      66.0       5.0       1.0         6M     224.0
# 2       1.0      66.0      13.0       1.0         5M   83577.0
# 3       1.0      66.0      23.0       6.0         4M     152.0
# 4       1.0      66.0      23.0       1.0         6E      95.0
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR              602
# ...

# %%
nov_df = pd.read_csv(nov_csv)

nov_df.head()
# Out:
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type Lic Xprdte  Lic Seqn  \
# 0         1        66         3         1         7L       150
# 1         1        66         5         1         6M       224
# 2         1        66        13         1         5M     83577
# 3         1        66        23         1         6E        95
# 4         1        66       121         6         6F       136
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4        RIOPEDRE-ABREU, ERNESTO                EJ ACCURACY GUNS
#
#                    Premise Street   Premise City Premise State  \
# 0    BO ASOMANTE CARR 115 KM 24-5         AGUADA            PR
# 1       BO PALMAR CARR 111 KM 1.8      AGUADILLA            PR
# ...

# %%
dec_df = pd.read_csv(dec_csv)

dec_df.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (0,1,2,3,5,11,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Lic Regn  Lic Dist  Lic Cnty  Lic Type  Lic Xprdte  Lic Seqn  \
# 0  --------  --------  --------  --------  ----------  --------
# 1         1        66       003        01          7L     00150
# 2         1        66       005        01          6M     00224
# 3         1        66       013        01          5M     83577
# 4         1        66       023        01          6E     00095
#
#                                         License Name  \
# 0  ----------------------------------------------...
# 1                             SALAZAR-MORET, CHARLES
# 2                         CARDONA-VALENTIN, VIRGINIA
# 3                        GUTIERREZ-MARTINEZ, ORLANDO
# 4                      ORTIZ-RODRIGUEZ, PABLO MANUEL
#
# ...

# %%
#Merging June-Dec-- but not July-- into one dataframe
df5 = pd.DataFrame(jun_df)
df6 = pd.DataFrame(aug_df)
df7 = pd.DataFrame(sep_df)
df8 = pd.DataFrame(oct_df)
df9 = pd.DataFrame(nov_df)
df10 = pd.DataFrame(dec_df)


mergedsfw_df = pd.concat([df5, df6, df7, df8, df9, df10])

mergedsfw_df.head()
# Out:
#   Lic Regn Lic Dist Lic Cnty Lic Type Lic Xprdte Lic Seqn  \
# 0        1       66        3        1         4L      150
# 1        1       66        5        1         6M      224
# 2        1       66       13        1         5M    83577
# 3        1       66       23        1         6E       95
# 4        1       66       23        6         4M      152
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR              602
# ...

# %%
#Merge the first part of the year & last part of the year into one dataframe
spring = pd.DataFrame(merged_df)
restofyear = pd.DataFrame(mergedsfw_df)


wholeyear_df = pd.concat([spring, restofyear])

wholeyear_df.head()
# Out:
#   Lic Regn Lic Dist Lic Cnty Lic Type Lic Xprdte Lic Seqn  \
# 0        1       66        3        1         4L      150
# 1        1       66        5        1         6M      224
# 2        1       66       13        1         5M    83577
# 3        1       66       23        6         4M      152
# 4        1       66       23        1         6E       95
#
#                     License Name                   Business Name  \
# 0         SALAZAR-MORET, CHARLES      AGUADA SPORT SHOP & ARMORY
# 1     CARDONA-VALENTIN, VIRGINIA  SHOOTING ACCESSORIES & SERVICE
# 2    GUTIERREZ-MARTINEZ, ORLANDO                    G G AND GUNS
# 3  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
# 4  ORTIZ-RODRIGUEZ, PABLO MANUEL          WEST SHOOTING SUPPLIES
#
#                    Premise Street Premise City Premise State Premise Zip Code  \
# 0    BO ASOMANTE CARR 115 KM 24-5       AGUADA            PR            00602
# ...

# %%
#Save the DataFrame of ALL the 2014 data to a CSV file
wholeyear_df.to_csv("wholeyear.csv", encoding='utf-8', index=False)

# %%
#drop columns that aren't needed (lic regn, lic dist, lic type, lic xprdte, mail street, mail city, mail state, mail zip code, voice phone)
wholeyear_df.drop(wholeyear_df.columns[[0, 1, 2, 4, 5, 12, 13, 14, 15, 16]], axis=1, inplace=True)

# %%
wholeyear_df.head(100)
# Out:
#    Lic Type                                 License Name  \
# 0         1                       SALAZAR-MORET, CHARLES
# 1         1                   CARDONA-VALENTIN, VIRGINIA
# 2         1                  GUTIERREZ-MARTINEZ, ORLANDO
# 3         6                ORTIZ-RODRIGUEZ, PABLO MANUEL
# 4         1                ORTIZ-RODRIGUEZ, PABLO MANUEL
# 5         8                      RIOPEDRE-ABREU, ERNESTO
# 6         6                      RIOPEDRE-ABREU, ERNESTO
# 7         1                      RIOPEDRE-ABREU, ERNESTO
# 8         1                               ANGOSTURA  INC
# 9         8                               ANGOSTURA  INC
# 10        1                       RI TACTICAL ARMORY INC
# 11        1               GONZALEZ-GERENA, HIRAM MODESTO
# 12        6               GONZALEZ-GERENA, HIRAM MODESTO
# 13        1                                 PEREZ, EDWIN
# 14        1                      CABAN-MARCIAL, CLOTILDE
# ...

# %%
#get data types of all columns
wholeyear_df.dtypes
wholeyear_df["Lic Type"] = pd.to_numeric(wholeyear_df["Lic Type"],errors = "coerce")
wholeyear_df["Lic Type"] = wholeyear_df["Lic Type"].fillna(0).astype(np.int64)
wholeyear_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lic Type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-93576c88e425> in <module>
#       1 #get data types of all columns
# ...

# %%
wholeyear_df.dtypes
wholeyear_df["Premise Zip Code"] = pd.to_numeric(wholeyear_df["Premise Zip Code"],errors = "coerce")
wholeyear_df["Premise Zip Code"] = wholeyear_df["Premise Zip Code"].fillna(0).astype(np.int64)
wholeyear_df.dtypes
# Out:
# Lic Type             int64
# License Name        object
# Business Name       object
# Premise Street      object
# Premise City        object
# Premise State       object
# Premise Zip Code     int64
# dtype: object

# %%
#rename column Lic Type to License

wholeyear_df = wholeyear_df.rename(index=str, columns={"Lic Type": "License"})
wholeyear_df.dtypes
# Out:
# License              int64
# License Name        object
# Business Name       object
# Premise Street      object
# Premise City        object
# Premise State       object
# Premise Zip Code     int64
# dtype: object

# %%
#Drop anything with license type 3
#to get rid of all 3 types (3, 6, 7, 10 altogether)
#
wholeyear_df.drop(wholeyear_df.loc[wholeyear_df['License'] ==3].index, inplace=True)
wholeyear_df
# Out:
#        License                         License Name  \
# 0            1               SALAZAR-MORET, CHARLES
# 1            1           CARDONA-VALENTIN, VIRGINIA
# 2            1          GUTIERREZ-MARTINEZ, ORLANDO
# 3            6        ORTIZ-RODRIGUEZ, PABLO MANUEL
# 4            1        ORTIZ-RODRIGUEZ, PABLO MANUEL
# 5            8              RIOPEDRE-ABREU, ERNESTO
# 6            6              RIOPEDRE-ABREU, ERNESTO
# 7            1              RIOPEDRE-ABREU, ERNESTO
# 8            1                       ANGOSTURA  INC
# 9            8                       ANGOSTURA  INC
# 10           1               RI TACTICAL ARMORY INC
# 11           1       GONZALEZ-GERENA, HIRAM MODESTO
# 12           6       GONZALEZ-GERENA, HIRAM MODESTO
# 13           1                         PEREZ, EDWIN
# 14           1              CABAN-MARCIAL, CLOTILDE
# 15           1  UNIFORM CITY THE TACTICAL STORE INC
# 16          11                SRC MANUFACTURING LLC
# ...

# %%
#Remove rows that have a license type of:
#3	Collector of Curios and Relics
#6	Manufacturer of Ammunition for Firearms
#7	Manufacturer of Firearms Other Than Destructive Devices
#10	Manufacturer of Destructive Devices

#Keeping the following license types: 
#1	Dealer in Firearms Other Than Destructive Devices (Includes Gunsmiths)
#2	Pawnbroker in Firearms Other Than Destructive Devices
#8	Importer of Firearms Other Than Destructive Devices
#9	Dealer in Destructive Devices
#11	Importer of Destructive Devices

# %%
#Drop anything with license type 6
wholeyear_df.drop(wholeyear_df.loc[wholeyear_df['License'] ==6].index, inplace=True)
wholeyear_df
# Out:
#        License                          License Name  \
# 0            1                SALAZAR-MORET, CHARLES
# 1            1            CARDONA-VALENTIN, VIRGINIA
# 2            1           GUTIERREZ-MARTINEZ, ORLANDO
# 8            1                        ANGOSTURA  INC
# 9            8                        ANGOSTURA  INC
# 10           1                RI TACTICAL ARMORY INC
# 11           1        GONZALEZ-GERENA, HIRAM MODESTO
# 15           1   UNIFORM CITY THE TACTICAL STORE INC
# 16          11                 SRC MANUFACTURING LLC
# 17          10                 SRC MANUFACTURING LLC
# 18           1                   DEPORTES TORMES INC
# 20           1         ECHEVARRIA, MARIBEL RODRIGUEZ
# 23           1                           JIMCAST INC
# 24           1               RIVERA-MILLAN, MAXIMINO
# 25           1                  ARLM ENTERPRISES INC
# 26           1                 RELOAD LA ARMERIA INC
# 27           1        ENCARNACION SANTIAGO, MIGUEL A
# ...

# %%
#Drop anything with license type 7
wholeyear_df.drop(wholeyear_df.loc[wholeyear_df['License'] ==7].index, inplace=True)
wholeyear_df
# Out:
#        License                          License Name  \
# 0            1                SALAZAR-MORET, CHARLES
# 1            1            CARDONA-VALENTIN, VIRGINIA
# 2            1           GUTIERREZ-MARTINEZ, ORLANDO
# 11           1        GONZALEZ-GERENA, HIRAM MODESTO
# 15           1   UNIFORM CITY THE TACTICAL STORE INC
# 16          11                 SRC MANUFACTURING LLC
# 17          10                 SRC MANUFACTURING LLC
# 18           1                   DEPORTES TORMES INC
# 20           1         ECHEVARRIA, MARIBEL RODRIGUEZ
# 23           1                           JIMCAST INC
# 24           1               RIVERA-MILLAN, MAXIMINO
# 25           1                  ARLM ENTERPRISES INC
# 26           1                 RELOAD LA ARMERIA INC
# 27           1        ENCARNACION SANTIAGO, MIGUEL A
# 28           1              GARCIA-GERENA, IVANGELES
# 29           1                  3T SHOOTING CLUB INC
# 30           1               RIVERA-MILLAN, MAXIMINO
# ...

# %%
#Drop anything with license type 10
wholeyear_df.drop(wholeyear_df.loc[wholeyear_df['License'] ==10].index, inplace=True)
wholeyear_df
# Out:
#        License                          License Name  \
# 0            1                SALAZAR-MORET, CHARLES
# 1            1            CARDONA-VALENTIN, VIRGINIA
# 2            1           GUTIERREZ-MARTINEZ, ORLANDO
# 11           1        GONZALEZ-GERENA, HIRAM MODESTO
# 20           1         ECHEVARRIA, MARIBEL RODRIGUEZ
# 23           1                           JIMCAST INC
# 24           1               RIVERA-MILLAN, MAXIMINO
# 25           1                  ARLM ENTERPRISES INC
# 26           1                 RELOAD LA ARMERIA INC
# 27           1        ENCARNACION SANTIAGO, MIGUEL A
# 28           1              GARCIA-GERENA, IVANGELES
# 29           1                  3T SHOOTING CLUB INC
# 30           1               RIVERA-MILLAN, MAXIMINO
# 31           1             PONT-COLON, ANGEL ALBERTO
# 32           1                       BML CORPORATION
# 33           1                     TACTICAL ARMS INC
# 34           1                         TRUPP, EDWARD
# ...

# %%
#save new cleaned df to CSV
wholeyear_df.to_csv("gunshop_info.csv", encoding='utf-8', index=False)

# %%
#merging together the Premise Street, City and State together
full_address = wholeyear_df["Premise Street"] + " " + wholeyear_df["Premise City"]+ ", " + wholeyear_df["Premise State"]
full_address.head()
# Out:
# 0               BO ASOMANTE CARR 115 KM 24-5 AGUADA, PR
# 1               BO PALMAR CARR 111 KM 1.8 AGUADILLA, PR
# 2                              BETANCES 165 ARECIBO, PR
# 11           CARRETERA 685 KILOMETRO 0.1 #23 MANATI, PR
# 20    CALLE SAN JOSE #51 EDIFICIO LITTLE PLAZA LOCAL...
# dtype: object

# %%
#appending the full_address to the DF. 

#First make the list into a Series
se = pd.Series(full_address)

#Then add the values to the DF
wholeyear_df['Full Address'] = se.values

# %%
#Delete "new_col" becasue i accidentally added it... 
del wholeyear_df["new_col"]
wholeyear_df.to_csv("gunshop_info.csv", encoding='utf-8', index=False)

# %%
#display DF
wholeyear_df
